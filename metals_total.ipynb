# %%
import pandas as pd
import os

# %%
medals_tot_df = pd.read_csv('data/medals_total.csv')

# %%
medals_tot_df.head()
# Out:
#    Rank Country Code  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 0     1          USA          39            41            33    113
# 1     2          CHN          38            32            18     88
# 2     3          JPN          27            14            17     58
# 3     4          GBR          22            21            22     65
# 4     5          ROC          20            28            23     71
#
#                       Country
# 0    United States of America
# 1  People's Republic of China
# 2                       Japan
# 3               Great Britain
# 4                         ROC

# %%
# Python SQL toolkit and Object Relational Mapper

import sqlalchemy
from sqlalchemy import create_engine, func

# %% [markdown]
# # Connect the code to Postgres SQL

# %%
rds_connection_string = "postgres:postgres@localhost:5432/olympics"
engine = create_engine(f'postgresql://{rds_connection_string}')
conn = engine.connect

# %%
medals_tot_df.to_sql(name='medals_total', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ...
