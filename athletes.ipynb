# %%
import pandas as pd
import os

# %%
athletes_pd = pd.read_csv('data/athletes.csv')

# %%
athletes_pd.head()
# Out:
#                 name  short_name  gender  birth_date birth_place  \
# 0    AALERUD Katrine   AALERUD K  Female  1994-12-04      VESTBY
# 1        ABAD Nestor      ABAD N    Male  1993-03-29       ALCOI
# 2  ABAGNALE Giovanni  ABAGNALE G    Male  1995-01-11    GRAGNANO
# 3     ABALDE Alberto    ABALDE A    Male  1995-12-15      FERROL
# 4      ABALDE Tamara    ABALDE T  Female  1989-02-06        VIGO
#
#   birth_country country country_code           discipline discipline_code  \
# 0        Norway  Norway          NOR         Cycling Road             CRD
# 1         Spain   Spain          ESP  Artistic Gymnastics             GAR
# 2         Italy   Italy          ITA               Rowing             ROW
# 3         Spain   Spain          ESP           Basketball             BKB
# 4         Spain   Spain          ESP           Basketball             BKB
#
#   residence_place residence_country height_m/ft  \
# 0             NaN               NaN         NaN
# ...

# %%
athletes_pd["name_length"] = athletes_pd["name"].str.len()
athletes_pd.head()
# Out:
#                 name  short_name  gender  birth_date birth_place  \
# 0    AALERUD Katrine   AALERUD K  Female  1994-12-04      VESTBY
# 1        ABAD Nestor      ABAD N    Male  1993-03-29       ALCOI
# 2  ABAGNALE Giovanni  ABAGNALE G    Male  1995-01-11    GRAGNANO
# 3     ABALDE Alberto    ABALDE A    Male  1995-12-15      FERROL
# 4      ABALDE Tamara    ABALDE T  Female  1989-02-06        VIGO
#
#   birth_country country country_code           discipline discipline_code  \
# 0        Norway  Norway          NOR         Cycling Road             CRD
# 1         Spain   Spain          ESP  Artistic Gymnastics             GAR
# 2         Italy   Italy          ITA               Rowing             ROW
# 3         Spain   Spain          ESP           Basketball             BKB
# 4         Spain   Spain          ESP           Basketball             BKB
#
#   residence_place residence_country height_m/ft  \
# 0             NaN               NaN         NaN
# ...

# %%
athletes_pd = athletes_pd.drop(columns=['short_name', 'birth_date', 'birth_place', 'birth_country', 'discipline_code', 'residence_place', 'residence_country', 'height_m/ft'])
athletes_pd.head()
# Out:
#                 name  gender country country_code           discipline  \
# 0    AALERUD Katrine  Female  Norway          NOR         Cycling Road
# 1        ABAD Nestor    Male   Spain          ESP  Artistic Gymnastics
# 2  ABAGNALE Giovanni    Male   Italy          ITA               Rowing
# 3     ABALDE Alberto    Male   Spain          ESP           Basketball
# 4      ABALDE Tamara  Female   Spain          ESP           Basketball
#
#                                                  url  name_length
# 0  ../../../en/results/cycling-road/athlete-profi...           15
# 1  ../../../en/results/artistic-gymnastics/athlet...           11
# 2  ../../../en/results/rowing/athlete-profile-n13...           17
# 3  ../../../en/results/basketball/athlete-profile...           14
# 4  ../../../en/results/basketball/athlete-profile...           13

# %%
athletes_pd.to_csv("data/cleaned_athletes.csv", index = False)

# %%
athletes_pd.to_json("data/cleaned_athletes.json", orient = 'index')
